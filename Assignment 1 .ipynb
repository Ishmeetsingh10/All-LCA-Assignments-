# %%
#Creating List
A = ["Ishmeet", "Sakshi", "Drishti", "Aditya", "Kuldeep"]
print(A)
# Out:
# ['Ishmeet', 'Sakshi', 'Drishti', 'Aditya', 'Kuldeep']

# %%
#Creating a Tuple 
B = ("1","2","3","4")
print(B)
# Out:
# ('1', '2', '3', '4')

# %%
#Creating dictionary
C = {
    1: "apple",
    2: "mango",
    3: "grape",
    4: "litchi",
}
print(C)

#Delete
del C[3]
print(C)

#Append
C[5]="orange"
print(C)

#Replace
C[2] = "banana"
print(C)
# Out:
# {1: 'apple', 2: 'mango', 3: 'grape', 4: 'litchi'}
# {1: 'apple', 2: 'mango', 4: 'litchi'}
# {1: 'apple', 2: 'mango', 4: 'litchi', 5: 'orange'}
# {1: 'apple', 2: 'banana', 4: 'litchi', 5: 'orange'}
